# %%
import geopandas
import random

# %%
a = geopandas.read_file("/home/daan/Documents/FATM_opt/save_files/grid_250.shp")

# %%
b = geopandas.read_file("../input_files/building_polygons/all_zones.shp")
c = list()

# %%
d=list()
for i in range(10):
    d.append(b.iloc[i,:])

# %%
newlen = 7000
l=list()
for i in range(len(b)):
    if 7000<random.uniform(0,1)*73192:
        l.append(i)

# %%
c=b.drop(l)

# %%
c
# Out:
#         osm_id_lef source addrstreet buildingma building addrhousen addrcity  \
# 0      393111341.0   None       None       None   school       None     None
# 14     506894890.0   None       None       None      yes       None     None
# 43     467247649.0   None       None       None      yes       None     None
# 68     467248578.0   None       None       None      yes       None     None
# 70     467248602.0   None       None       None      yes       None     None
# ...            ...    ...        ...        ...      ...        ...      ...
# 73122  507017183.0   None       None       None      yes       None     None
# 73159  507017221.0   None       None       None      yes       None     None
# 73183  507017245.0   None       None       None      yes       None     None
# 73184  507017246.0   None       None       None      yes       None     None
# 73185  507017247.0   None       None       None      yes       None     None
#
#       office buildingle addrfull  ... access_rig  populati_1  refugee_ri  \
# 0       None       None     None  ...       None        None         yes
# 14      None       None     None  ...       None        None         yes
# 43      None       None     None  ...       None        None         yes
# 68      None       None     None  ...       None        None         yes
# 70      None       None     None  ...       None        None         yes
# ...      ...        ...      ...  ...        ...         ...         ...
# 73122   None       None     None  ...       None        None         yes
# 73159   None       None     None  ...       None        None         yes
# 73183   None       None     None  ...       None        None         yes
# 73184   None       None     None  ...       None        None         yes
# 73185   None       None     None  ...       None        None         yes
#
#         landuse_ri place_righ loc_name_r type_right operator_r    id  \
# 0      residential       None       None   boundary       None  None
# 14     residential       None       None   boundary       None  None
# 43     residential       None       None       None       None  None
# 68     residential       None       None       None       None  None
# 70     residential       None       None       None       None  None
# ...            ...        ...        ...        ...        ...   ...
# 73122  residential       None       None   boundary       None  None
# 73159  residential       None       None   boundary       None  None
# 73183  residential       None       None   boundary       None  None
# 73184  residential       None       None   boundary       None  None
# 73185  residential       None       None   boundary       None  None
#
#                                                 geometry
# 0      POLYGON ((31.25068 3.30989, 31.25071 3.30997, ...
# 14     POLYGON ((31.25046 3.31025, 31.25047 3.31028, ...
# 43     POLYGON ((31.31084 3.39092, 31.31086 3.39093, ...
# 68     POLYGON ((31.30929 3.36840, 31.30931 3.36840, ...
# 70     POLYGON ((31.30868 3.37217, 31.30869 3.37223, ...
# ...                                                  ...
# 73122  POLYGON ((31.28681 3.29704, 31.28681 3.29706, ...
# 73159  POLYGON ((31.28683 3.29662, 31.28684 3.29665, ...
# 73183  POLYGON ((31.28695 3.29614, 31.28695 3.29616, ...
# 73184  POLYGON ((31.28690 3.29608, 31.28690 3.29611, ...
# 73185  POLYGON ((31.28589 3.29598, 31.28589 3.29601, ...
#
# [7053 rows x 49 columns]
